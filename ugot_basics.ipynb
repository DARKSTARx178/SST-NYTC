# %%
from ugot import ugot
got = ugot.UGOT()
got.initialize('192.168.88.1')
# Out:
# 192.168.88.1:50051

# %%
#Straight movement
got.mecanum_translate_speed_times(angle=0,speed=30,times=70,unit=1)

#Movement without duration
got.mecanum_translate_speed(angle=90,speed=20)

#Turning movement
got.mecanum_turn_speed_times(turn=3,speed=45,times=180,unit=2)

#Turning without duration
got.mecanum_turn_speed(turn=2,speed=20) # turn: left 2, right 3

#Stop the robot
got.mecanum_stop()

#Load models
got.load_models(['apriltag_qrcode'])

#Get the apriltag info
got.get_apriltag_total_info()

#Play a tone
got.play_tone(tone="C5",beat=4,wait=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 #Straight movement
# ----> 2 got.mecanum_translate_speed_times(angle=0,speed=30,times=70,unit=1)
#       4 #Movement without duration
#       5 got.mecanum_translate_speed(angle=90,speed=20)
#
# File ~/Desktop/National-Youth-Tech-Championship-2026/venv/lib/python3.13/site-packages/ugot/ugot.py:818, in UGOT.mecanum_translate_speed_times(self, angle, speed, times, unit)
#     816     self.MODEL.mecanum_move_control(linear_speed=speed, direction=angle, time=times)
#     817 elif unit == E_Model.Unit.mileage:
# --> 818     self.MODEL.mecanum_move_control(linear_speed=speed, direction=angle, mileage=times)
#     819 else:
#     820     self.__print_move_unit_m_error_msg(sys._getframe().f_code.co_name, unit)
#
# File ~/Desktop/National-Youth-Tech-Championship-2026/venv/lib/python3.13/site-packages/ugot/src/model_client.py:63, in ModelClient.mecanum_move_control(self, linear_speed, direction, rotate_speed, time, mileage, target_angle, client_type)
#      60 def mecanum_move_control(self, linear_speed=0, direction=0, rotate_speed=0, time=0, mileage=0, target_angle=0,
#      61                            client_type=0):
# ---> 63     response = self.model_move_control(linear_speed, direction, rotate_speed, time, mileage, target_angle,
#      64                                         model_type=MODEL_TYPE_MECANUM, client_type=client_type)
#      65     return response
#
# File ~/Desktop/National-Youth-Tech-Championship-2026/venv/lib/python3.13/site-packages/ugot/src/model_client.py:56, in ModelClient.model_move_control(self, linear_speed, direction, rotate_speed, time, mileage, target_angle, model_type, client_type)
#      53 input_data.params.mileage = mileage
#      54 input_data.params.target_angle = target_angle
# ---> 56 response = self.client.modelCommonControl(input_data)
#      57 return response
#
# File ~/Desktop/National-Youth-Tech-Championship-2026/venv/lib/python3.13/site-packages/grpc/_channel.py:1156, in _UnaryUnaryMultiCallable.__call__(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#    1147 def __call__(
#    1148     self,
#    1149     request: Any,
#    (...)   1154     compression: Optional[grpc.Compression] = None,
#    1155 ) -> Any:
# -> 1156     state, call = self._blocking(
#    1157         request, timeout, metadata, credentials, wait_for_ready, compression
#    1158     )
#    1159     return _end_unary_response_blocking(state, call, False, None)
#
# File ~/Desktop/National-Youth-Tech-Championship-2026/venv/lib/python3.13/site-packages/grpc/_channel.py:1143, in _UnaryUnaryMultiCallable._blocking(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#    1126 state.target = _common.decode(self._target)
#    1127 call = self._channel.segregated_call(
#    1128     cygrpc.PropagationConstants.GRPC_PROPAGATE_DEFAULTS,
#    1129     self._method,
#    (...)   1141     self._registered_call_handle,
#    1142 )
# -> 1143 event = call.next_event()
#    1144 _handle_event(event, state, self._response_deserializer)
#    1145 return state, call
#
# File src/python/grpcio/grpc/_cython/_cygrpc/channel.pyx.pxi:388, in grpc._cython.cygrpc.SegregatedCall.next_event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/channel.pyx.pxi:211, in grpc._cython.cygrpc._next_call_event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/channel.pyx.pxi:205, in grpc._cython.cygrpc._next_call_event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/completion_queue.pyx.pxi:97, in grpc._cython.cygrpc._latent_event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/completion_queue.pyx.pxi:80, in grpc._cython.cygrpc._internal_latent_event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/completion_queue.pyx.pxi:61, in grpc._cython.cygrpc._next()
#
# KeyboardInterrupt:
